# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.19.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-135474
# aml-quickstarts-135474
# southcentralus
# 9b72f9e6-56c5-4c16-991b-19c652994860

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = "automl-exp"
project_folder = "./automl-project"

exp = Experiment(ws, experiment_name)
exp
# Out:
# Experiment(Name: automl-exp,
# Workspace: quick-starts-ws-135474)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
cluster_name = "AML-Cluster"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS12_v2',
                                                           min_nodes=1, max_nodes=5)
    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
compute_target.get_status()
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key =  "Bank-marketing"
description_text = "Bank-Marketing Dataset for Second Project"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 3,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             enable_onnx_compatible_models=True,
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = exp.submit(pipeline)
# Out:
# Created step automl_module [cb4489d7][c21878f1-3376-4056-af5a-49a159ae37af], (This step will run and generate new outputs)
# Submitted PipelineRun c331246b-caff-4603-80fc-6cd845bd2701
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/automl-exp/runs/c331246b-caff-4603-80fc-6cd845bd2701?wsid=/subscriptions/9b72f9e6-56c5-4c16-991b-19c652994860/resourcegroups/aml-quickstarts-135474/workspaces/quick-starts-ws-135474

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: c331246b-caff-4603-80fc-6cd845bd2701
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/automl-exp/runs/c331246b-caff-4603-80fc-6cd845bd2701?wsid=/subscriptions/9b72f9e6-56c5-4c16-991b-19c652994860/resourcegroups/aml-quickstarts-135474/workspaces/quick-starts-ws-135474
# PipelineRun Status: Running
#
#
# StepRunId: c9e42245-a544-468c-8a76-f578fef4fcc0
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/automl-exp/runs/c9e42245-a544-468c-8a76-f578fef4fcc0?wsid=/subscriptions/9b72f9e6-56c5-4c16-991b-19c652994860/resourcegroups/aml-quickstarts-135474/workspaces/quick-starts-ws-135474
# StepRun( automl_module ) Status: NotStarted
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': 'c9e42245-a544-468c-8a76-f578fef4fcc0', 'target': 'AML-Cluster', 'status': 'Completed', 'startTimeUtc': '2021-01-20T13:24:56.686392Z', 'endTimeUtc': '2021-01-20T14:03:32.009516Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': 'd270cd7a-7303-4ac2-b93d-957a60fb8fa2', 'StepType': 'AutoMLStep', 'azureml.moduleid': 'c21878f1-3376-4056-af5a-49a159ae37af', 'azureml.nodeid': 'cb4489d7', 'azureml.pipelinerunid': 'c331246b-caff-4603-80fc-6cd845bd2701', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'AML-Cluster', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "9b72f9e6-56c5-4c16-991b-19c652994860", "resource_group": "aml-quickstarts-135474", "workspace_name": "quick-starts-ws-135474", "region": "southcentralus", "compute_target": "AML-Cluster", "spark_service": null, "azure_service": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 3, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["LinearSVM", "AveragedPerceptronClassifier", "GradientBoosting", "BernoulliNaiveBayes", "MultinomialNaiveBayes", "LogisticRegression", "SVM", "DecisionTree", "KNN", "LightGBM", "SGD", "RandomForest", "ExtremeRandomTrees", "XGBoostClassifier", "TensorFlowDNN", "TensorFlowLinearClassifier"], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": true, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_DS12_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "SDK-1.13.0", "environment_label": null, "force_text_dnn": false, "enable_feature_sweeping": false, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_ensembling": true, "enable_stack_ensembling": false, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "_local_managed_run_id": null, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"a779e951-ad1e-43e2-94ec-60525a70fc57\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': 'd270cd7a-7303-4ac2-b93d-957a60fb8fa2', 'SetupRunId': 'c9e42245-a544-468c-8a76-f578fef4fcc0_setup', 'SetupRunContainerId': 'dcid.c9e42245-a544-468c-8a76-f578fef4fcc0_setup', 'FeaturizationRunJsonPath': 'featurizer_container.json', 'FeaturizationRunId': 'c9e42245-a544-468c-8a76-f578fef4fcc0_featurize', 'ProblemInfoJsonString': '{"dataset_num_categorical": 0, "is_sparse": true, "subsampling": false, "dataset_classes": 2, "dataset_ ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'c331246b-caff-4603-80fc-6cd845bd2701', 'status': 'Completed', 'startTimeUtc': '2021-01-20T13:24:19.711244Z', 'endTimeUtc': '2021-01-20T14:05:06.13702Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg135474.blob.core.windows.net/azureml/ExperimentRun/dcid.c331246b-caff-4603-80fc-6cd845bd2701/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=uwUyfnZDlXBdHxFjZz6O05nm4CFvDBkwa3vmgmG%2BsJ8%3D&st=2021-01-20T13%3A55%3A07Z&se=2021-01-20T22%3A05%3A07Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg135474.blob.core.windows.net/azureml/ExperimentRun/dcid.c331246b-caff-4603-80fc-6cd845bd2701/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=WVzHVGRCeQu4BBo3QjrJ1mJcameoUlUdmFQqNnfY1a0%3D&st=2021-01-20T13%3A55%3A07Z&se=2021-01-20T22%3A05%3A07Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg135474.blob.core.windows.net/azureml/ExperimentRun/dcid.c331246b-caff-4603-80fc-6cd845bd2701/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=U593FVAot99uQixl2ef%2FzynmYhCMCGVWfbx93C8OR%2Bo%3D&st=2021-01-20T13%3A55%3A07Z&se=2021-01-20T22%3A05%3A07Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/c9e42245-a544-468c-8a76-f578fef4fcc0/metrics_data
# Downloaded azureml/c9e42245-a544-468c-8a76-f578fef4fcc0/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  c9e42245-a544-468c-8a76-f578fef4fcc0_19  \
# log_loss                                           [0.22589233807484954]
# f1_score_weighted                                   [0.8719631449552753]
# matthews_correlation                                [0.3256750549961802]
# balanced_accuracy                                   [0.5827905869626023]
# f1_score_micro                                      [0.9004552352048558]
# average_precision_score_weighted                     [0.945222197717833]
# precision_score_weighted                            [0.8859664258327548]
# accuracy                                            [0.9004552352048558]
# recall_score_micro                                  [0.9004552352048558]
# AUC_weighted                                        [0.9304904908242522]
# average_precision_score_macro                        [0.787108791806625]
# norm_macro_recall                                  [0.16558117392520466]
# precision_score_macro                               [0.8202786854702324]
# f1_score_macro                                      [0.6136146528695394]
# recall_score_weighted                               [0.9004552352048558]
# AUC_micro                                           [0.9744804861368561]
# recall_score_macro                                  [0.5827905869626023]
# precision_score_micro                               [0.9004552352048558]
# weighted_accuracy                                   [0.9793227746800656]
# average_precision_score_micro                       [0.9756497344937594]
# AUC_macro                                           [0.9304904908242521]
#
#                                  c9e42245-a544-468c-8a76-f578fef4fcc0_5  \
# log_loss                                           [0.2371677628971085]
# f1_score_weighted                                  [0.8734704046383025]
# matthews_correlation                              [0.31999379338174755]
# balanced_accuracy                                  [0.5942781010175104]
# f1_score_micro                                     [0.8977238239757208]
# average_precision_score_weighted                   [0.9304482463520353]
# precision_score_weighted                            [0.877014103638037]
# accuracy                                           [0.8977238239757208]
# recall_score_micro                                 [0.8977238239757208]
# AUC_weighted                                       [0.9045266529220316]
# average_precision_score_macro                      [0.7342203339068372]
# norm_macro_recall                                 [0.18855620203502088]
# precision_score_macro                               [0.771526544069397]
# f1_score_macro                                     [0.6263947343363969]
# recall_score_weighted                              [0.8977238239757208]
# AUC_micro                                          [0.9688175167690964]
# recall_score_macro                                 [0.5942781010175104]
# precision_score_micro                              [0.8977238239757208]
# weighted_accuracy                                  [0.9730611889183236]
# average_precision_score_micro                      [0.9698446978349575]
# AUC_macro                                          [0.9045266529220316]
#
#                                  c9e42245-a544-468c-8a76-f578fef4fcc0_15  \
# log_loss                                            [0.2589772567400724]
# f1_score_weighted                                   [0.8353395018439429]
# matthews_correlation                                               [0.0]
# balanced_accuracy                                                  [0.5]
# f1_score_micro                                      [0.8880121396054628]
# average_precision_score_weighted                    [0.9227934226317158]
# precision_score_weighted                             [0.788565560086672]
# accuracy                                            [0.8880121396054628]
# recall_score_micro                                  [0.8880121396054628]
# AUC_weighted                                        [0.8807490826104433]
# average_precision_score_macro                       [0.7130066653604958]
# norm_macro_recall                                                  [0.0]
# precision_score_macro                               [0.4440060698027314]
# f1_score_macro                                      [0.4703423886834914]
# recall_score_weighted                               [0.8880121396054628]
# AUC_micro                                           [0.9637405274465152]
# recall_score_macro                                                 [0.5]
# precision_score_micro                               [0.8880121396054628]
# weighted_accuracy                                   [0.9843450583187134]
# average_precision_score_micro                       [0.9647659061754628]
# AUC_macro                                           [0.8807490826104432]
#
#                                  c9e42245-a544-468c-8a76-f578fef4fcc0_23  \
# log_loss                                           [0.18354087685416373]
# f1_score_weighted                                    [0.908914057592548]
# matthews_correlation                                [0.5265756963424171]
# balanced_accuracy                                   [0.7401814773445069]
# f1_score_micro                                      [0.9128983308042489]
# average_precision_score_weighted                    [0.9512932336269386]
# precision_score_weighted                            [0.9065343959710289]
# accuracy                                            [0.9128983308042489]
# recall_score_micro                                  [0.9128983308042489]
# AUC_weighted                                        [0.9428782599514307]
# average_precision_score_macro                       [0.8078135890376441]
# norm_macro_recall                                   [0.4803629546890138]
# precision_score_macro                               [0.7886171396772399]
# f1_score_macro                                      [0.7612649763995245]
# recall_score_weighted                               [0.9128983308042489]
# AUC_micro                                           [0.9788788365136859]
# recall_score_macro                                  [0.7401814773445069]
# precision_score_micro                               [0.9128983308042489]
# weighted_accuracy                                    [0.955779253606468]
# average_precision_score_micro                       [0.9798597961315479]
# AUC_macro                                           [0.9428782599514307]
#
#                                  c9e42245-a544-468c-8a76-f578fef4fcc0_26  \
# log_loss                                           [0.18363290147206127]
# f1_score_weighted                                   [0.9026101481496257]
# matthews_correlation                               [0.49097989542264636]
# balanced_accuracy                                   [0.7195145105928161]
# f1_score_micro                                      [0.9077389984825494]
# average_precision_score_weighted                    [0.9516347743373957]
# precision_score_weighted                            [0.8997107792040071]
# accuracy                                            [0.9077389984825494]
# recall_score_micro                                  [0.9077389984825494]
# AUC_weighted                                         [0.941788136268239]
# average_precision_score_macro                       [0.8097317189961571]
# norm_macro_recall                                  [0.43902902118563225]
# precision_score_macro                               [0.7745390920379569]
# f1_score_macro                                      [0.7426775834997985]
# recall_score_weighted                               [0.9077389984825494]
# AUC_micro                                           [0.9786961897941656]
# recall_score_macro                                  [0.7195145105928161]
# precision_score_micro                               [0.9077389984825494]
# weighted_accuracy                                   [0.9544700474393217]
# average_precision_score_micro                       [0.9797233708196674]
# AUC_macro                                            [0.941788136268239]
#
#                                  c9e42245-a544-468c-8a76-f578fef4fcc0_40  \
# log_loss                                            [0.3543630368390971]
# f1_score_weighted                                   [0.8353395018439429]
# matthews_correlation                                               [0.0]
# balanced_accuracy                                                  [0.5]
# f1_score_micro                                      [0.8880121396054628]
# average_precision_score_weighted                    [0.8011068409624182]
# precision_score_weighted                             [0.788565560086672]
# accuracy                                            [0.8880121396054628]
# recall_score_micro                                  [0.8880121396054628]
# AUC_weighted                                                       [0.5]
# average_precision_score_macro                                      [0.5]
# norm_macro_recall                                                  [0.0]
# precision_score_macro                               [0.4440060698027314]
# f1_score_macro                                      [0.4703423886834914]
# recall_score_weighted                               [0.8880121396054628]
# AUC_micro                                           [0.8880121396054628]
# recall_score_macro                                                 [0.5]
# precision_score_micro                               [0.8880121396054628]
# weighted_accuracy                                   [0.9843450583187134]
# average_precision_score_micro                       [0.8445594902839405]
# AUC_macro                                                          [0.5]
#
#                                  c9e42245-a544-468c-8a76-f578fef4fcc0_11  \
# log_loss                                            [0.4875466606859961]
# f1_score_weighted                                    [0.714458980599595]
# matthews_correlation                                [0.3749881733222925]
# balanced_accuracy                                   [0.7962103151448465]
# f1_score_micro                                      [0.6506828528072838]
# average_precision_score_weighted                    [0.9300792676059012]
# precision_score_weighted                            [0.9119878555518418]
# accuracy                                            [0.6506828528072838]
# recall_score_micro                                  [0.6506828528072838]
# AUC_weighted                                        [0.8939759783790593]
# average_precision_score_macro                       [0.7377817460992299]
# norm_macro_recall                                    [0.592420630289693]
# precision_score_macro                                [0.618679298915391]
# f1_score_macro                                      [0.5712846533257234]
# recall_score_weighted                               [0.6506828528072838]
# AUC_micro                                              [0.8273070201091]
# recall_score_macro                                  [0.7962103151448465]
# precision_score_micro                               [0.6506828528072838]
# weighted_accuracy                                   [0.6145523203601162]
# average_precision_score_micro                       [0.8474315577305115]
# AUC_macro                                           [0.8939759783790593]
#
#                                  c9e42245-a544-468c-8a76-f578fef4fcc0_30  \
# log_loss                                           [0.27886826325499686]
# f1_score_weighted                                   [0.8353395018439429]
# matthews_correlation                                               [0.0]
# balanced_accuracy                                                  [0.5]
# f1_score_micro                                      [0.8880121396054628]
# average_precision_score_weighted                     [0.934815549451594]
# precision_score_weighted                             [0.788565560086672]
# accuracy                                            [0.8880121396054628]
# recall_score_micro                                  [0.8880121396054628]
# AUC_weighted                                        [0.9127442590215378]
# average_precision_score_macro                       [0.7498338311109191]
# norm_macro_recall                                                  [0.0]
# precision_score_macro                               [0.4440060698027314]
# f1_score_macro                                      [0.4703423886834914]
# recall_score_weighted                               [0.8880121396054628]
# AUC_micro                                           [0.9701041491568823]
# recall_score_macro                                                 [0.5]
# precision_score_micro                               [0.8880121396054628]
# weighted_accuracy                                   [0.9843450583187134]
# average_precision_score_micro                       [0.9712889079706248]
# AUC_macro                                           [0.9127442590215377]
#
#                                  c9e42245-a544-468c-8a76-f578fef4fcc0_37  \
# log_loss                                            [0.1833499775510563]
# f1_score_weighted                                   [0.9047827589840839]
# matthews_correlation                                [0.5023934957967708]
# balanced_accuracy                                   [0.7242630782425391]
# f1_score_micro                                      [0.9098634294385431]
# average_precision_score_weighted                    [0.9505073763146729]
# precision_score_weighted                            [0.9020298926502925]
# accuracy                                            [0.9098634294385433]
# recall_score_micro                                  [0.9098634294385433]
# AUC_weighted                                        [0.9417788743847793]
# average_precision_score_macro                       [0.8048441454917021]
# norm_macro_recall                                   [0.4485261564850782]
# precision_score_macro                               [0.7813651121228389]
# f1_score_macro                                      [0.7482613812485128]
# recall_score_weighted                               [0.9098634294385433]
# AUC_micro                                           [0.9785831754094698]
# recall_score_macro                                  [0.7242630782425391]
# precision_score_micro                               [0.9098634294385433]
# weighted_accuracy                                   [0.9559429762359593]
# average_precision_score_micro                       [0.9795889846730903]
# AUC_macro                                           [0.9417788743847793]
#
#                                  c9e42245-a544-468c-8a76-f578fef4fcc0_42  ...  \
# log_loss                                           [0.18212320322735842]  ...
# f1_score_weighted                                    [0.912294877094483]  ...
# matthews_correlation                                [0.5476651690313282]  ...
# balanced_accuracy                                   [0.7567713629972936]  ...
# f1_score_micro                                      [0.9150227617602428]  ...
# average_precision_score_weighted                    [0.9529012007897981]  ...
# precision_score_weighted                            [0.9103936567676629]  ...
# accuracy                                            [0.9150227617602428]  ...
# recall_score_micro                                  [0.9150227617602428]  ...
# AUC_weighted                                         [0.943697010449257]  ...
# average_precision_score_macro                       [0.8146358499907052]  ...
# norm_macro_recall                                   [0.5135427259945873]  ...
# precision_score_macro                               [0.7920274421073921]  ...
# f1_score_macro                                      [0.7727908552875257]  ...
# recall_score_weighted                               [0.9150227617602428]  ...
# AUC_micro                                           [0.9792477220969833]  ...
# recall_score_macro                                  [0.7567713629972936]  ...
# precision_score_micro                               [0.9150227617602428]  ...
# weighted_accuracy                                   [0.9543123034451771]  ...
# average_precision_score_micro                       [0.9802204735535665]  ...
# AUC_macro                                           [0.9436970104492569]  ...
#
#                                  c9e42245-a544-468c-8a76-f578fef4fcc0_7  \
# log_loss                                          [0.27639648818540713]
# f1_score_weighted                                  [0.8353395018439429]
# matthews_correlation                                              [0.0]
# balanced_accuracy                                                 [0.5]
# f1_score_micro                                     [0.8880121396054628]
# average_precision_score_weighted                   [0.9226984342677297]
# precision_score_weighted                            [0.788565560086672]
# accuracy                                           [0.8880121396054628]
# recall_score_micro                                 [0.8880121396054628]
# AUC_weighted                                         [0.85868403455053]
# average_precision_score_macro                      [0.7255066939533774]
# norm_macro_recall                                                 [0.0]
# precision_score_macro                              [0.4440060698027314]
# f1_score_macro                                     [0.4703423886834914]
# recall_score_weighted                              [0.8880121396054628]
# AUC_micro                                          [0.9593519403335627]
# recall_score_macro                                                [0.5]
# precision_score_micro                              [0.8880121396054628]
# weighted_accuracy                                  [0.9843450583187134]
# average_precision_score_micro                      [0.9606007160050718]
# AUC_macro                                            [0.85868403455053]
#
#                                  c9e42245-a544-468c-8a76-f578fef4fcc0_22  \
# log_loss                                           [0.18115151864375498]
# f1_score_weighted                                   [0.9100415644605403]
# matthews_correlation                                [0.5357619178216784]
# balanced_accuracy                                   [0.7508386635472644]
# f1_score_micro                                      [0.9128983308042489]
# average_precision_score_weighted                    [0.9516860732237478]
# precision_score_weighted                            [0.9080335867085474]
# accuracy                                            [0.9128983308042489]
# recall_score_micro                                  [0.9128983308042489]
# AUC_weighted                                        [0.9448491887516278]
# average_precision_score_macro                       [0.8085204474402641]
# norm_macro_recall                                   [0.5016773270945287]
# precision_score_macro                               [0.7860811293290488]
# f1_score_macro                                      [0.7668111420906795]
# recall_score_weighted                               [0.9128983308042489]
# AUC_micro                                           [0.9793693944704005]
# recall_score_macro                                  [0.7508386635472644]
# precision_score_micro                               [0.9128983308042489]
# weighted_accuracy                                   [0.9531333625443325]
# average_precision_score_micro                        [0.980352027134298]
# AUC_macro                                           [0.9448491887516277]
#
#                                  c9e42245-a544-468c-8a76-f578fef4fcc0_36  \
# log_loss                                           [0.17953984826011166]
# f1_score_weighted                                   [0.9071553913821001]
# matthews_correlation                                [0.5195442529553999]
# balanced_accuracy                                   [0.7411826869464866]
# f1_score_micro                                      [0.9104704097116844]
# average_precision_score_weighted                    [0.9525965806282052]
# precision_score_weighted                            [0.9048930721424753]
# accuracy                                            [0.9104704097116844]
# recall_score_micro                                  [0.9104704097116844]
# AUC_weighted                                        [0.9442545758335231]
# average_precision_score_macro                       [0.8129296078280362]
# norm_macro_recall                                   [0.4823653738929732]
# precision_score_macro                               [0.7797943689453914]
# f1_score_macro                                      [0.7584448322812782]
# recall_score_weighted                               [0.9104704097116844]
# AUC_micro                                           [0.9793498679426453]
# recall_score_macro                                  [0.7411826869464866]
# precision_score_micro                               [0.9104704097116844]
# weighted_accuracy                                   [0.9524999721188641]
# average_precision_score_micro                       [0.9803278107514134]
# AUC_macro                                           [0.9442545758335232]
#
#                                  c9e42245-a544-468c-8a76-f578fef4fcc0_46  \
# log_loss                                           [0.17630331389060627]
# f1_score_weighted                                   [0.9130754860350586]
# matthews_correlation                                [0.5502859517794709]
# balanced_accuracy                                   [0.7550866263959974]
# f1_score_micro                                      [0.9162367223065252]
# average_precision_score_weighted                    [0.9550353180571559]
# precision_score_weighted                            [0.9110525050912751]
# accuracy                                            [0.9162367223065251]
# recall_score_micro                                  [0.9162367223065251]
# AUC_weighted                                        [0.9469127363864206]
# average_precision_score_macro                       [0.8226419846865102]
# norm_macro_recall                                   [0.5101732527919949]
# precision_score_macro                               [0.7967762687171883]
# f1_score_macro                                      [0.7737085697223052]
# recall_score_weighted                               [0.9162367223065251]
# AUC_micro                                           [0.9803100757343748]
# recall_score_macro                                  [0.7550866263959974]
# precision_score_micro                               [0.9162367223065251]
# weighted_accuracy                                   [0.9562459320847722]
# average_precision_score_micro                       [0.9812255463921877]
# AUC_macro                                           [0.9469127363864207]
#
#                                  c9e42245-a544-468c-8a76-f578fef4fcc0_13  \
# log_loss                                           [0.33655623030329523]
# f1_score_weighted                                    [0.885603431576398]
# matthews_correlation                                [0.3976739324324451]
# balanced_accuracy                                   [0.6227454260188535]
# f1_score_micro                                      [0.9062215477996965]
# average_precision_score_weighted                     [0.947605275820125]
# precision_score_weighted                            [0.8929725418691179]
# accuracy                                            [0.9062215477996965]
# recall_score_micro                                  [0.9062215477996965]
# AUC_weighted                                        [0.9308878256246675]
# average_precision_score_macro                       [0.7985126174047921]
# norm_macro_recall                                  [0.24549085203770704]
# precision_score_macro                                [0.822098675416211]
# f1_score_macro                                      [0.6650154684677185]
# recall_score_weighted                               [0.9062215477996965]
# AUC_micro                                           [0.9758990146932517]
# recall_score_macro                                  [0.6227454260188535]
# precision_score_micro                               [0.9062215477996965]
# weighted_accuracy                                   [0.9766010009385309]
# average_precision_score_micro                       [0.9766643355999638]
# AUC_macro                                           [0.9308878256246677]
#
#                                  c9e42245-a544-468c-8a76-f578fef4fcc0_16  \
# log_loss                                            [0.5404073821170334]
# f1_score_weighted                                   [0.8329780314553044]
# matthews_correlation                                 [0.391626915880452]
# balanced_accuracy                                    [0.766802445878184]
# f1_score_micro                                      [0.8045523520485584]
# average_precision_score_weighted                     [0.908364114190526]
# precision_score_weighted                             [0.887788044892981]
# accuracy                                            [0.8045523520485585]
# recall_score_micro                                  [0.8045523520485585]
# AUC_weighted                                        [0.8203384477453798]
# average_precision_score_macro                       [0.7015881244210624]
# norm_macro_recall                                    [0.533604891756368]
# precision_score_macro                               [0.6437127391553793]
# f1_score_macro                                      [0.6662705492464752]
# recall_score_weighted                               [0.8045523520485585]
# AUC_micro                                           [0.8095304192446826]
# recall_score_macro                                   [0.766802445878184]
# precision_score_micro                               [0.8045523520485585]
# weighted_accuracy                                   [0.8139246326329785]
# average_precision_score_micro                       [0.7606175378138146]
# AUC_macro                                           [0.8203384477453797]
#
#                                  c9e42245-a544-468c-8a76-f578fef4fcc0_29  \
# log_loss                                           [0.22401907490539805]
# f1_score_weighted                                   [0.8353395018439429]
# matthews_correlation                                               [0.0]
# balanced_accuracy                                                  [0.5]
# f1_score_micro                                      [0.8880121396054628]
# average_precision_score_weighted                    [0.9325958554040306]
# precision_score_weighted                             [0.788565560086672]
# accuracy                                            [0.8880121396054628]
# recall_score_micro                                  [0.8880121396054628]
# AUC_weighted                                        [0.9090320961309407]
# average_precision_score_macro                       [0.7414530728086027]
# norm_macro_recall                                                  [0.0]
# precision_score_macro                               [0.4440060698027314]
# f1_score_macro                                      [0.4703423886834914]
# recall_score_weighted                               [0.8880121396054628]
# AUC_micro                                           [0.9693658253527094]
# recall_score_macro                                                 [0.5]
# precision_score_micro                               [0.8880121396054628]
# weighted_accuracy                                   [0.9843450583187134]
# average_precision_score_micro                       [0.9704088038448857]
# AUC_macro                                           [0.9090320961309408]
#
#                                  c9e42245-a544-468c-8a76-f578fef4fcc0_32  \
# log_loss                                            [0.2284274894507082]
# f1_score_weighted                                   [0.8903953583012578]
# matthews_correlation                               [0.41636682765647687]
# balanced_accuracy                                   [0.6682189583344911]
# f1_score_micro                                      [0.9007587253414264]
# average_precision_score_weighted                     [0.937540547626302]
# precision_score_weighted                            [0.8867247421523131]
# accuracy                                            [0.9007587253414264]
# recall_score_micro                                  [0.9007587253414264]
# AUC_weighted                                        [0.9222742740072651]
# average_precision_score_macro                       [0.7614755381998957]
# norm_macro_recall                                  [0.33643791666898215]
# precision_score_macro                               [0.7576423859848216]
# f1_score_macro                                      [0.6997541387206018]
# recall_score_weighted                               [0.9007587253414264]
# AUC_micro                                           [0.9697665797030035]
# recall_score_macro                                  [0.6682189583344911]
# precision_score_micro                               [0.9007587253414264]
# weighted_accuracy                                   [0.9584920593949829]
# average_precision_score_micro                         [0.96650544585801]
# AUC_macro                                            [0.922274274007265]
#
#                                  c9e42245-a544-468c-8a76-f578fef4fcc0_4  \
# log_loss                                            [0.275209050839576]
# f1_score_weighted                                  [0.8353395018439429]
# matthews_correlation                                              [0.0]
# balanced_accuracy                                                 [0.5]
# f1_score_micro                                     [0.8880121396054628]
# average_precision_score_weighted                   [0.9212528489062117]
# precision_score_weighted                            [0.788565560086672]
# accuracy                                           [0.8880121396054628]
# recall_score_micro                                 [0.8880121396054628]
# AUC_weighted                                       [0.8707957995506135]
# average_precision_score_macro                        [0.71394374533213]
# norm_macro_recall                                                 [0.0]
# precision_score_macro                              [0.4440060698027314]
# f1_score_macro                                     [0.4703423886834914]
# recall_score_weighted                              [0.8880121396054628]
# AUC_micro                                          [0.9617608875359502]
# recall_score_macro                                                [0.5]
# precision_score_micro                              [0.8880121396054628]
# weighted_accuracy                                  [0.9843450583187134]
# average_precision_score_micro                      [0.9625320768459462]
# AUC_macro                                          [0.8707957995506135]
#
#                                  c9e42245-a544-468c-8a76-f578fef4fcc0_10
# log_loss                                            [0.5239285044152949]
# f1_score_weighted                                   [0.8029177989782792]
# matthews_correlation                               [0.35617289974518856]
# balanced_accuracy                                   [0.7567588594546233]
# f1_score_micro                                      [0.7635811836115326]
# average_precision_score_weighted                    [0.9246202938594243]
# precision_score_weighted                            [0.8847430291960088]
# accuracy                                            [0.7635811836115326]
# recall_score_micro                                  [0.7635811836115326]
# AUC_weighted                                         [0.871260283006111]
# average_precision_score_macro                       [0.7263672643946015]
# norm_macro_recall                                   [0.5135177189092466]
# precision_score_macro                               [0.6235197246770329]
# f1_score_macro                                      [0.6332993748757988]
# recall_score_weighted                               [0.7635811836115326]
# AUC_micro                                             [0.84731471098206]
# recall_score_macro                                  [0.7567588594546233]
# precision_score_micro                               [0.7635811836115326]
# weighted_accuracy                                   [0.7652749821589474]
# average_precision_score_micro                       [0.8299645636212455]
# AUC_macro                                            [0.871260283006111]
#
# [21 rows x 45 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/c9e42245-a544-468c-8a76-f578fef4fcc0/model_data
# Downloaded azureml/c9e42245-a544-468c-8a76-f578fef4fcc0/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                 n_jobs=1,
#                                                                                                                                 nthread=None,
#                                                                                                                                 objective='reg:logistic',
#                                                                                                                                 random_state=0,
#                                                                                                                                 reg_alpha=1.875,
#                                                                                                                                 reg_lambda=1.9791666666666667,
#                                                                                                                                 scale_pos_weight=1,
#                                                                                                                                 seed=None,
#                                                                                                                                 silent=None,
#                                                                                                                                 subsample=0.6,
#                                                                                                                                 tree_method='auto',
#                                                                                                                                 verbose=-10,
#                                                                                                                                 verbosity=0))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.4,
#                                                                                          0.1,
#                                                                                          0.2,
#                                                                                          0.2,
#                                                                                          0.1]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('31',
#                                              Pipeline(memory=None,
#                                                       steps=[('standardscalerwrapper',
#                                                               <azureml.automl.runtime.shared.model_wrappers.StandardScalerWrapper object at 0x7f7f3afa4f28>),
#                                                              ('xgboostclassifier',
#                                                               XGBoostClassifier(base_score=0.5,
#                                                                                 booster='gbtree',
#                                                                                 colsample_bylevel=1,
#                                                                                 colsample_bynode=1,
#                                                                                 colsample_bytree=1,
#                                                                                 e...
#                                                                                 max_depth=6,
#                                                                                 max_leaves=15,
#                                                                                 min_child_weight=1,
#                                                                                 missing=nan,
#                                                                                 n_estimators=100,
#                                                                                 n_jobs=1,
#                                                                                 nthread=None,
#                                                                                 objective='reg:logistic',
#                                                                                 random_state=0,
#                                                                                 reg_alpha=1.875,
#                                                                                 reg_lambda=1.9791666666666667,
#                                                                                 scale_pos_weight=1,
#                                                                                 seed=None,
#                                                                                 silent=None,
#                                                                                 subsample=0.6,
#                                                                                 tree_method='auto',
#                                                                                 verbose=-10,
#                                                                                 verbosity=0))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.4, 0.1, 0.2, 0.2, 0.1]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_d13efda4_5b28_11eb_a8a7_7bbaf25c8111row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_d13efda4_5b28_11eb_a8a7_7bbaf25c8111row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_d13efda4_5b28_11eb_a8a7_7bbaf25c8111row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_d13efda4_5b28_11eb_a8a7_7bbaf25c8111row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_d13efda4_5b28_11eb_a8a7_7bbaf25c8111" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d13efda4_5b28_11eb_a8a7_7bbaf25c8111level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d13efda4_5b28_11eb_a8a7_7bbaf25c8111row0_col0" class="data row0 col0" >28645</td>
#                         <td id="T_d13efda4_5b28_11eb_a8a7_7bbaf25c8111row0_col1" class="data row0 col1" >613</td>
#             </tr>
#             <tr>
#                         <th id="T_d13efda4_5b28_11eb_a8a7_7bbaf25c8111level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d13efda4_5b28_11eb_a8a7_7bbaf25c8111row1_col0" class="data row1 col0" >1111</td>
#                         <td id="T_d13efda4_5b28_11eb_a8a7_7bbaf25c8111row1_col1" class="data row1 col1" >2581</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: ca0256d4-a0f6-4697-9e0b-0194ad6f0ebe,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/9b72f9e6-56c5-4c16-991b-19c652994860/resourceGroups/aml-quickstarts-135474/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-135474/PipelineRuns/PipelineSubmit/ca0256d4-a0f6-4697-9e0b-0194ad6f0ebe)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  fdc595b0-bfc9-4ebb-a49a-5661a701a90b

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
