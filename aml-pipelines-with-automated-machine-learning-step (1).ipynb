# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.19.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-134528
# aml-quickstarts-134528
# southcentralus
# 976ee174-3882-4721-b90a-b5fef6b72f24

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = "automl-exp"
project_folder = "./automl-project"

exp = Experiment(ws, experiment_name)
exp
# Out:
# Experiment(Name: automl-exp,
# Workspace: quick-starts-ws-134528)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
cluster_name = "AML-Cluster"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS12_v2',
                                                           min_nodes=1, max_nodes=5)
    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
compute_target.get_status()
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "Bank-marketing"
description_text = "Bank-Marketing Dataset for Project"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 30,
    "max_concurrent_iterations": 3,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             enable_onnx_compatible_models=True,
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = exp.submit(pipeline)
# Out:
# Created step automl_module [d9e7c3ab][762f29f6-06a9-40f8-9b04-3ae4882467eb], (This step will run and generate new outputs)
# Submitted PipelineRun d5e530a8-4321-4b7c-855a-77ec881bf3be
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/automl-exp/runs/d5e530a8-4321-4b7c-855a-77ec881bf3be?wsid=/subscriptions/976ee174-3882-4721-b90a-b5fef6b72f24/resourcegroups/aml-quickstarts-134528/workspaces/quick-starts-ws-134528

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# WARNING:azureml.pipeline.core.run:Expected a StepRun object but received <class 'azureml.core.run.Run'> instead.
# This usually indicates a package conflict with one of the dependencies of azureml-core or azureml-pipeline-core.
# Please check for package conflicts in your python environment
# PipelineRunId: d5e530a8-4321-4b7c-855a-77ec881bf3be
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/automl-exp/runs/d5e530a8-4321-4b7c-855a-77ec881bf3be?wsid=/subscriptions/976ee174-3882-4721-b90a-b5fef6b72f24/resourcegroups/aml-quickstarts-134528/workspaces/quick-starts-ws-134528
# PipelineRun Status: Running
#
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'd5e530a8-4321-4b7c-855a-77ec881bf3be', 'status': 'Completed', 'startTimeUtc': '2021-01-13T11:56:00.801695Z', 'endTimeUtc': '2021-01-13T12:37:09.346929Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg134528.blob.core.windows.net/azureml/ExperimentRun/dcid.d5e530a8-4321-4b7c-855a-77ec881bf3be/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=WyHk94mvTjpW20EJnZrURVsaiiaIP0yGwCezX24zW0E%3D&st=2021-01-13T12%3A27%3A10Z&se=2021-01-13T20%3A37%3A10Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg134528.blob.core.windows.net/azureml/ExperimentRun/dcid.d5e530a8-4321-4b7c-855a-77ec881bf3be/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=33ggbZ1vI1gwuihOhXA4ckolKvd88JoBdaT0FpAF8%2Bs%3D&st=2021-01-13T12%3A27%3A10Z&se=2021-01-13T20%3A37%3A10Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg134528.blob.core.windows.net/azureml/ExperimentRun/dcid.d5e530a8-4321-4b7c-855a-77ec881bf3be/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=6HE1U%2FRCC%2FuQZ%2F4%2FHasKfBz3UsVXp11%2FDZ%2BdEBt85kA%3D&st=2021-01-13T12%3A27%3A10Z&se=2021-01-13T20%3A37%3A10Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/5ff758a3-16db-40dd-b88d-7b382156b52f/metrics_data
# Downloaded azureml/5ff758a3-16db-40dd-b88d-7b382156b52f/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  5ff758a3-16db-40dd-b88d-7b382156b52f_6  \
# AUC_micro                                           [0.964897474216003]
# average_precision_score_macro                      [0.7408702724260071]
# recall_score_weighted                              [0.9004552352048558]
# AUC_weighted                                       [0.8845788714209766]
# precision_score_weighted                           [0.8846432293746505]
# precision_score_macro                              [0.8108634868421052]
# accuracy                                           [0.9004552352048558]
# matthews_correlation                               [0.3299029184605347]
# recall_score_macro                                 [0.5875271141638279]
# log_loss                                          [0.25482138685032407]
# AUC_macro                                          [0.8845788714209766]
# norm_macro_recall                                 [0.17505422832765571]
# precision_score_micro                              [0.9004552352048558]
# f1_score_micro                                     [0.9004552352048558]
# average_precision_score_weighted                   [0.9290100284825984]
# weighted_accuracy                                  [0.9781468230968942]
# balanced_accuracy                                  [0.5875271141638279]
# recall_score_micro                                 [0.9004552352048558]
# f1_score_weighted                                  [0.8732899740852763]
# f1_score_macro                                     [0.6197805847321197]
# average_precision_score_micro                      [0.9657348126124763]
#
#                                  5ff758a3-16db-40dd-b88d-7b382156b52f_11  \
# AUC_micro                                           [0.8547643576394086]
# average_precision_score_macro                       [0.7344223767964773]
# recall_score_weighted                                [0.723823975720789]
# AUC_weighted                                        [0.8936221744309037]
# precision_score_weighted                            [0.9076945548160545]
# precision_score_macro                               [0.6330700976042591]
# accuracy                                             [0.723823975720789]
# matthews_correlation                               [0.40786209360806436]
# recall_score_macro                                  [0.8125260490472301]
# log_loss                                             [0.496999800697788]
# AUC_macro                                           [0.8936221744309036]
# norm_macro_recall                                   [0.6250520980944603]
# precision_score_micro                                [0.723823975720789]
# f1_score_micro                                       [0.723823975720789]
# average_precision_score_weighted                    [0.9293164645429485]
# weighted_accuracy                                    [0.701801650264319]
# balanced_accuracy                                   [0.8125260490472301]
# recall_score_micro                                   [0.723823975720789]
# f1_score_weighted                                   [0.7743195487423042]
# f1_score_macro                                      [0.6234817213871473]
# average_precision_score_micro                       [0.8667900792624554]
#
#                                  5ff758a3-16db-40dd-b88d-7b382156b52f_14  \
# AUC_micro                                           [0.9682858794190857]
# average_precision_score_macro                        [0.746764515566932]
# recall_score_weighted                               [0.8883156297420334]
# AUC_weighted                                        [0.9036009276702474]
# precision_score_weighted                            [0.9007928150046113]
# precision_score_macro                               [0.9441408621736491]
# accuracy                                            [0.8883156297420334]
# matthews_correlation                              [0.049063912865329386]
# recall_score_macro                                  [0.5013550135501355]
# log_loss                                            [0.2384234924976181]
# AUC_macro                                           [0.9036009276702472]
# norm_macro_recall                                [0.0027100271002709064]
# precision_score_micro                               [0.8883156297420334]
# f1_score_micro                                      [0.8883156297420334]
# average_precision_score_weighted                    [0.9325600114204273]
# weighted_accuracy                                   [0.9843874836349229]
# balanced_accuracy                                   [0.5013550135501355]
# recall_score_micro                                  [0.8883156297420334]
# f1_score_weighted                                   [0.8360791405851395]
# f1_score_macro                                     [0.47312070913357085]
# average_precision_score_micro                       [0.9690754895966394]
#
#                                  5ff758a3-16db-40dd-b88d-7b382156b52f_42  \
# AUC_micro                                           [0.9709446188067173]
# average_precision_score_macro                       [0.7605901920843283]
# recall_score_weighted                               [0.8983308042488619]
# AUC_weighted                                        [0.9137024008654304]
# precision_score_weighted                            [0.8785065010861672]
# precision_score_macro                               [0.7806479235050663]
# accuracy                                            [0.8983308042488619]
# matthews_correlation                               [0.31973674237620686]
# recall_score_macro                                  [0.5910674691162496]
# log_loss                                           [0.21813394441132458]
# AUC_macro                                           [0.9137024008654304]
# norm_macro_recall                                  [0.18213493823249927]
# precision_score_micro                               [0.8983308042488619]
# f1_score_micro                                      [0.8983308042488619]
# average_precision_score_weighted                    [0.9375434376698557]
# weighted_accuracy                                   [0.9746159790297066]
# balanced_accuracy                                   [0.5910674691162496]
# recall_score_micro                                  [0.8983308042488619]
# f1_score_weighted                                    [0.872998540240218]
# f1_score_macro                                      [0.6229035631355757]
# average_precision_score_micro                        [0.972279942045232]
#
#                                  5ff758a3-16db-40dd-b88d-7b382156b52f_12  \
# AUC_micro                                           [0.8461589615939911]
# average_precision_score_macro                       [0.7376778945529524]
# recall_score_weighted                               [0.7435508345978755]
# AUC_weighted                                        [0.8679547167993895]
# precision_score_weighted                            [0.8804215728922431]
# precision_score_macro                                [0.612444177931525]
# accuracy                                            [0.7435508345978755]
# matthews_correlation                                [0.3298692181891885]
# recall_score_macro                                  [0.7419282685649824]
# log_loss                                            [0.5783951775269008]
# AUC_macro                                           [0.8679547167993895]
# norm_macro_recall                                   [0.4838565371299648]
# precision_score_micro                               [0.7435508345978755]
# f1_score_micro                                      [0.7435508345978755]
# average_precision_score_weighted                    [0.9264255378064119]
# weighted_accuracy                                   [0.7439536738541744]
# balanced_accuracy                                   [0.7419282685649824]
# recall_score_micro                                  [0.7435508345978755]
# f1_score_weighted                                   [0.7876402629462246]
# f1_score_macro                                       [0.614996054237605]
# average_precision_score_micro                       [0.8460624171137788]
#
#                                  5ff758a3-16db-40dd-b88d-7b382156b52f_8  \
# AUC_micro                                          [0.9652510701596432]
# average_precision_score_macro                       [0.731760058077036]
# recall_score_weighted                              [0.8880121396054628]
# AUC_weighted                                       [0.8883438270472931]
# precision_score_weighted                            [0.788565560086672]
# precision_score_macro                              [0.4440060698027314]
# accuracy                                           [0.8880121396054628]
# matthews_correlation                                              [0.0]
# recall_score_macro                                                [0.5]
# log_loss                                          [0.27752311805980523]
# AUC_macro                                           [0.888343827047293]
# norm_macro_recall                                                 [0.0]
# precision_score_micro                              [0.8880121396054628]
# f1_score_micro                                     [0.8880121396054628]
# average_precision_score_weighted                    [0.926667468866524]
# weighted_accuracy                                  [0.9843450583187134]
# balanced_accuracy                                                 [0.5]
# recall_score_micro                                 [0.8880121396054628]
# f1_score_weighted                                  [0.8353395018439429]
# f1_score_macro                                     [0.4703423886834914]
# average_precision_score_micro                      [0.9652335257862639]
#
#                                  5ff758a3-16db-40dd-b88d-7b382156b52f_9  \
# AUC_micro                                          [0.8240565900879846]
# average_precision_score_macro                      [0.7200161357019156]
# recall_score_weighted                              [0.7247344461305008]
# AUC_weighted                                       [0.8294669600831346]
# precision_score_weighted                           [0.8776588879176677]
# precision_score_macro                              [0.6042128755751601]
# accuracy                                           [0.7247344461305008]
# matthews_correlation                              [0.31053463369505147]
# recall_score_macro                                  [0.731333600075577]
# log_loss                                           [0.5605085620258126]
# AUC_macro                                          [0.8294669600831347]
# norm_macro_recall                                 [0.46266720015115403]
# precision_score_micro                              [0.7247344461305008]
# f1_score_micro                                     [0.7247344461305008]
# average_precision_score_weighted                   [0.9143883559374915]
# weighted_accuracy                                  [0.7230960547100322]
# balanced_accuracy                                   [0.731333600075577]
# recall_score_micro                                 [0.7247344461305008]
# f1_score_weighted                                  [0.7733049216950421]
# f1_score_macro                                     [0.5996060321586332]
# average_precision_score_micro                      [0.8010425277367099]
#
#                                  5ff758a3-16db-40dd-b88d-7b382156b52f_21  \
# AUC_micro                                           [0.9793693944704005]
# average_precision_score_macro                       [0.8085204474402641]
# recall_score_weighted                               [0.9128983308042489]
# AUC_weighted                                        [0.9448491887516278]
# precision_score_weighted                            [0.9080335867085474]
# precision_score_macro                               [0.7860811293290488]
# accuracy                                            [0.9128983308042489]
# matthews_correlation                                [0.5357619178216784]
# recall_score_macro                                  [0.7508386635472644]
# log_loss                                           [0.18115151864375498]
# AUC_macro                                           [0.9448491887516277]
# norm_macro_recall                                   [0.5016773270945287]
# precision_score_micro                               [0.9128983308042489]
# f1_score_micro                                      [0.9128983308042489]
# average_precision_score_weighted                    [0.9516860732237478]
# weighted_accuracy                                   [0.9531333625443325]
# balanced_accuracy                                   [0.7508386635472644]
# recall_score_micro                                  [0.9128983308042489]
# f1_score_weighted                                   [0.9100415644605403]
# f1_score_macro                                      [0.7668111420906795]
# average_precision_score_micro                        [0.980352027134298]
#
#                                  5ff758a3-16db-40dd-b88d-7b382156b52f_40  \
# AUC_micro                                           [0.9750066892173501]
# average_precision_score_macro                       [0.7975305733240465]
# recall_score_weighted                               [0.9083459787556905]
# AUC_weighted                                         [0.924852319268237]
# precision_score_weighted                            [0.9003961976098999]
# precision_score_macro                               [0.7764474757209578]
# accuracy                                            [0.9083459787556905]
# matthews_correlation                               [0.49439280836757793]
# recall_score_macro                                  [0.7210404058927807]
# log_loss                                           [0.32494091061912267]
# AUC_macro                                            [0.924852319268237]
# norm_macro_recall                                  [0.44208081178556147]
# precision_score_micro                               [0.9083459787556905]
# f1_score_micro                                      [0.9083459787556905]
# average_precision_score_weighted                    [0.9454557805421987]
# weighted_accuracy                                   [0.9548488859675335]
# balanced_accuracy                                   [0.7210404058927807]
# recall_score_micro                                  [0.9083459787556905]
# f1_score_weighted                                   [0.9032508708591674]
# f1_score_macro                                      [0.7443704941346683]
# average_precision_score_micro                       [0.9743680823755341]
#
#                                  5ff758a3-16db-40dd-b88d-7b382156b52f_35  ...  \
# AUC_micro                                            [0.979170260729804]  ...
# average_precision_score_macro                       [0.8181072826091123]  ...
# recall_score_weighted                               [0.9122913505311078]  ...
# AUC_weighted                                        [0.9419705953723926]  ...
# precision_score_weighted                             [0.905387728519385]  ...
# precision_score_macro                               [0.7877039852928842]  ...
# accuracy                                            [0.9122913505311078]  ...
# matthews_correlation                                [0.5201542992321688]  ...
# recall_score_macro                                  [0.7351031866436231]  ...
# log_loss                                           [0.18922964483162014]  ...
# AUC_macro                                           [0.9419705953723925]  ...
# norm_macro_recall                                   [0.4702063732872461]  ...
# precision_score_micro                               [0.9122913505311078]  ...
# f1_score_micro                                      [0.9122913505311078]  ...
# average_precision_score_weighted                    [0.9534503522832329]  ...
# weighted_accuracy                                   [0.9562823787656349]  ...
# balanced_accuracy                                   [0.7351031866436231]  ...
# recall_score_micro                                  [0.9122913505311078]  ...
# f1_score_weighted                                   [0.9078853847841633]  ...
# f1_score_macro                                      [0.7576713259183312]  ...
# average_precision_score_micro                       [0.9801169112452911]  ...
#
#                                  5ff758a3-16db-40dd-b88d-7b382156b52f_46  \
# AUC_micro                                            [0.980636592436694]
# average_precision_score_macro                       [0.8262868594328714]
# recall_score_weighted                                 [0.91350531107739]
# AUC_weighted                                         [0.947857448499297]
# precision_score_weighted                            [0.9085132071198092]
# precision_score_macro                               [0.7880904729732601]
# accuracy                                              [0.91350531107739]
# matthews_correlation                                [0.5380062751662786]
# recall_score_macro                                  [0.7511804270469224]
# log_loss                                           [0.17464070821295213]
# AUC_macro                                            [0.947857448499297]
# norm_macro_recall                                   [0.5023608540938449]
# precision_score_micro                                 [0.91350531107739]
# f1_score_micro                                        [0.91350531107739]
# average_precision_score_weighted                    [0.9559464038728506]
# weighted_accuracy                                    [0.953806188968337]
# balanced_accuracy                                   [0.7511804270469224]
# recall_score_micro                                    [0.91350531107739]
# f1_score_weighted                                   [0.9105473303191152]
# f1_score_macro                                      [0.7678387114717825]
# average_precision_score_micro                       [0.9815339017605077]
#
#                                  5ff758a3-16db-40dd-b88d-7b382156b52f_23  \
# AUC_micro                                           [0.9788269806876192]
# average_precision_score_macro                       [0.8089530041542754]
# recall_score_weighted                               [0.9101669195751139]
# AUC_weighted                                        [0.9426189272145626]
# precision_score_weighted                            [0.9053820950242154]
# precision_score_macro                               [0.7779362994341406]
# accuracy                                            [0.9101669195751139]
# matthews_correlation                                 [0.522694488583068]
# recall_score_macro                                  [0.7457483323978831]
# log_loss                                           [0.18234374308249698]
# AUC_macro                                           [0.9426189272145626]
# norm_macro_recall                                  [0.49149666479576615]
# precision_score_micro                               [0.9101669195751139]
# f1_score_micro                                      [0.9101669195751139]
# average_precision_score_weighted                    [0.9515123279241607]
# weighted_accuracy                                   [0.9509876073236905]
# balanced_accuracy                                   [0.7457483323978831]
# recall_score_micro                                  [0.9101669195751139]
# f1_score_weighted                                   [0.9074077133908034]
# f1_score_macro                                      [0.7604225006140997]
# average_precision_score_micro                       [0.9798157361762464]
#
#                                  5ff758a3-16db-40dd-b88d-7b382156b52f_30  \
# AUC_micro                                           [0.9788862050147255]
# average_precision_score_macro                       [0.8101845152999028]
# recall_score_weighted                               [0.9128983308042489]
# AUC_weighted                                        [0.9424920394111663]
# precision_score_weighted                             [0.907019636133764]
# precision_score_macro                               [0.7877194593684469]
# accuracy                                            [0.9128983308042489]
# matthews_correlation                                [0.5296299768558868]
# recall_score_macro                                   [0.743733872745426]
# log_loss                                            [0.1816076074356531]
# AUC_macro                                           [0.9424920394111664]
# norm_macro_recall                                  [0.48746774549085203]
# precision_score_micro                               [0.9128983308042489]
# f1_score_micro                                      [0.9128983308042489]
# average_precision_score_weighted                    [0.9517838306968476]
# weighted_accuracy                                   [0.9548972899190897]
# balanced_accuracy                                    [0.743733872745426]
# recall_score_micro                                  [0.9128983308042489]
# f1_score_weighted                                   [0.9092974412848348]
# f1_score_macro                                      [0.7631470523778217]
# average_precision_score_micro                       [0.9798810767294689]
#
#                                  5ff758a3-16db-40dd-b88d-7b382156b52f_41  \
# AUC_micro                                           [0.8149554781351244]
# average_precision_score_macro                       [0.7120717096824258]
# recall_score_weighted                               [0.7047040971168437]
# AUC_weighted                                        [0.8574123779515307]
# precision_score_weighted                            [0.8757110993587777]
# precision_score_macro                               [0.5971984211851311]
# accuracy                                            [0.7047040971168437]
# matthews_correlation                               [0.29406957939934797]
# recall_score_macro                                  [0.7224236681874678]
# log_loss                                            [0.5343039286418457]
# AUC_macro                                           [0.8574123779515308]
# norm_macro_recall                                   [0.4448473363749357]
# precision_score_micro                               [0.7047040971168437]
# f1_score_micro                                      [0.7047040971168437]
# average_precision_score_weighted                    [0.9195197408589286]
# weighted_accuracy                                   [0.7003048069262952]
# balanced_accuracy                                   [0.7224236681874678]
# recall_score_micro                                  [0.7047040971168437]
# f1_score_weighted                                   [0.7579320774824435]
# f1_score_macro                                      [0.5845512548138593]
# average_precision_score_micro                       [0.7942735188202322]
#
#                                  5ff758a3-16db-40dd-b88d-7b382156b52f_1  \
# AUC_micro                                          [0.9781770788959222]
# average_precision_score_macro                      [0.8065229883244922]
# recall_score_weighted                              [0.9071320182094081]
# AUC_weighted                                       [0.9392346349984347]
# precision_score_weighted                           [0.8991976076061607]
# precision_score_macro                              [0.7723958081530135]
# accuracy                                           [0.9071320182094081]
# matthews_correlation                                [0.488678780261868]
# recall_score_macro                                 [0.7191727470931578]
# log_loss                                           [0.1874363495858499]
# AUC_macro                                          [0.9392346349984347]
# norm_macro_recall                                 [0.43834549418631563]
# precision_score_micro                              [0.9071320182094081]
# f1_score_micro                                     [0.9071320182094081]
# average_precision_score_weighted                   [0.9505970434373063]
# weighted_accuracy                                  [0.9537972210153172]
# balanced_accuracy                                  [0.7191727470931578]
# recall_score_micro                                 [0.9071320182094081]
# f1_score_weighted                                  [0.9021127651963996]
# f1_score_macro                                     [0.7416848907681176]
# average_precision_score_micro                      [0.9791945367231853]
#
#                                  5ff758a3-16db-40dd-b88d-7b382156b52f_38  \
# AUC_micro                                           [0.8788154213516134]
# average_precision_score_macro                       [0.7546493096149272]
# recall_score_weighted                               [0.7781487101669196]
# AUC_weighted                                         [0.913927927727671]
# precision_score_weighted                            [0.9131230346052736]
# precision_score_macro                               [0.6567119294129474]
# accuracy                                            [0.7781487101669196]
# matthews_correlation                                [0.4621640545960358]
# recall_score_macro                                  [0.8407456186660295]
# log_loss                                           [0.42275682947975024]
# AUC_macro                                           [0.9139279277276711]
# norm_macro_recall                                    [0.681491237332059]
# precision_score_micro                               [0.7781487101669196]
# f1_score_micro                                      [0.7781487101669197]
# average_precision_score_weighted                    [0.9361325164951236]
# weighted_accuracy                                   [0.7626075910043154]
# balanced_accuracy                                   [0.8407456186660295]
# recall_score_micro                                  [0.7781487101669196]
# f1_score_weighted                                   [0.8166419970069944]
# f1_score_macro                                      [0.6703903856398756]
# average_precision_score_micro                       [0.8893903627277364]
#
#                                  5ff758a3-16db-40dd-b88d-7b382156b52f_0  \
# AUC_micro                                           [0.979695082216353]
# average_precision_score_macro                      [0.8151093723721079]
# recall_score_weighted                              [0.9116843702579667]
# AUC_weighted                                       [0.9450464668693167]
# precision_score_weighted                           [0.9072720074188747]
# precision_score_macro                              [0.7819118765348991]
# accuracy                                           [0.9116843702579667]
# matthews_correlation                               [0.5323740218566827]
# recall_score_macro                                 [0.7513392683482543]
# log_loss                                          [0.17775706110025447]
# AUC_macro                                          [0.9450464668693166]
# norm_macro_recall                                  [0.5026785366965085]
# precision_score_micro                              [0.9116843702579667]
# f1_score_micro                                     [0.9116843702579667]
# average_precision_score_weighted                   [0.9531771295804466]
# weighted_accuracy                                  [0.9514937218005303]
# balanced_accuracy                                  [0.7513392683482543]
# recall_score_micro                                 [0.9116843702579667]
# f1_score_weighted                                  [0.9091539479147899]
# f1_score_macro                                     [0.7653697272147331]
# average_precision_score_micro                      [0.9806603102489483]
#
#                                  5ff758a3-16db-40dd-b88d-7b382156b52f_27  \
# AUC_micro                                           [0.9788629942364506]
# average_precision_score_macro                       [0.8089325091475965]
# recall_score_weighted                               [0.9098634294385433]
# AUC_weighted                                        [0.9423457016525052]
# precision_score_weighted                            [0.9026804625146836]
# precision_score_macro                                [0.780234819685955]
# accuracy                                            [0.9098634294385433]
# matthews_correlation                                [0.5066504244138683]
# recall_score_macro                                  [0.7289996054437646]
# log_loss                                           [0.18279927212031324]
# AUC_macro                                           [0.9423457016525052]
# norm_macro_recall                                  [0.45799921088752926]
# precision_score_micro                               [0.9098634294385433]
# f1_score_micro                                      [0.9098634294385431]
# average_precision_score_weighted                    [0.9514823604411914]
# weighted_accuracy                                    [0.954767024652788]
# balanced_accuracy                                   [0.7289996054437646]
# recall_score_micro                                  [0.9098634294385433]
# f1_score_weighted                                   [0.9053354992418561]
# f1_score_macro                                      [0.7509632657361396]
# average_precision_score_micro                       [0.9798553536942687]
#
#                                  5ff758a3-16db-40dd-b88d-7b382156b52f_16  \
# AUC_micro                                           [0.8384469962996308]
# average_precision_score_macro                       [0.7182693973599277]
# recall_score_weighted                               [0.7028831562974204]
# AUC_weighted                                        [0.8693926242064881]
# precision_score_weighted                             [0.879791487792995]
# precision_score_macro                                [0.600904555836038]
# accuracy                                            [0.7028831562974204]
# matthews_correlation                               [0.30682208458381366]
# recall_score_macro                                   [0.733239695691557]
# log_loss                                            [0.5029884816586729]
# AUC_macro                                           [0.8693926242064881]
# norm_macro_recall                                    [0.466479391383114]
# precision_score_micro                               [0.7028831562974204]
# f1_score_micro                                      [0.7028831562974204]
# average_precision_score_weighted                    [0.9223432023984457]
# weighted_accuracy                                   [0.6953464486963528]
# balanced_accuracy                                    [0.733239695691557]
# recall_score_micro                                  [0.7028831562974204]
# f1_score_weighted                                    [0.756762742449388]
# f1_score_macro                                      [0.5868859214992261]
# average_precision_score_micro                       [0.8136684433720024]
#
#                                  5ff758a3-16db-40dd-b88d-7b382156b52f_5
# AUC_micro                                          [0.9680449294350892]
# average_precision_score_macro                      [0.7349034497190025]
# recall_score_weighted                              [0.9001517450682853]
# AUC_weighted                                       [0.9005486739761452]
# precision_score_weighted                           [0.8827113977984437]
# precision_score_macro                              [0.7979300898726163]
# accuracy                                           [0.9001517450682853]
# matthews_correlation                              [0.33340661446628406]
# recall_score_macro                                 [0.5932768914155307]
# log_loss                                          [0.23784242043344245]
# AUC_macro                                          [0.9005486739761451]
# norm_macro_recall                                  [0.1865537828310615]
# precision_score_micro                              [0.9001517450682853]
# f1_score_micro                                     [0.9001517450682853]
# average_precision_score_weighted                   [0.9301695133181466]
# weighted_accuracy                                  [0.9763404704059276]
# balanced_accuracy                                  [0.5932768914155307]
# recall_score_micro                                 [0.9001517450682853]
# f1_score_weighted                                  [0.8746567304785686]
# f1_score_macro                                     [0.6267831475663812]
# average_precision_score_micro                      [0.9691037040765922]
#
# [21 rows x 44 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/5ff758a3-16db-40dd-b88d-7b382156b52f/model_data
# Downloaded azureml/5ff758a3-16db-40dd-b88d-7b382156b52f/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                 reg_lambda=0,
#                                                                                                                                 scale_pos_weight=1,
#                                                                                                                                 seed=None,
#                                                                                                                                 silent=None,
#                                                                                                                                 subsample=1,
#                                                                                                                                 tree_method='auto',
#                                                                                                                                 verbose=-10,
#                                                                                                                                 verbosity=0))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.3333333333333333,
#                                                                                          0.2,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667,
#                                                                                          0.13333333333333333,
#                                                                                          0.13333333333333333]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('32',
#                                              Pipeline(memory=None,
#                                                       steps=[('sparsenormalizer',
#                                                               <azureml.automl.runtime.shared.model_wrappers.SparseNormalizer object at 0x7ff1e550ef98>),
#                                                              ('xgboostclassifier',
#                                                               XGBoostClassifier(base_score=0.5,
#                                                                                 booster='gbtree',
#                                                                                 colsample_bylevel=1,
#                                                                                 colsample_bynode=1,
#                                                                                 colsample_bytree=0.8,
#                                                                                 eta=0.05,...
#                                                                                 nthread=None,
#                                                                                 objective='reg:logistic',
#                                                                                 random_state=0,
#                                                                                 reg_alpha=0.625,
#                                                                                 reg_lambda=0,
#                                                                                 scale_pos_weight=1,
#                                                                                 seed=None,
#                                                                                 silent=None,
#                                                                                 subsample=1,
#                                                                                 tree_method='auto',
#                                                                                 verbose=-10,
#                                                                                 verbosity=0))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.3333333333333333, 0.2,
#                                          0.06666666666666667, 0.06666666666666667,
#                                          0.06666666666666667, 0.13333333333333333,
#                                          0.13333333333333333]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_35753e64_559d_11eb_aa14_000d3aebc696row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_35753e64_559d_11eb_aa14_000d3aebc696row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_35753e64_559d_11eb_aa14_000d3aebc696row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_35753e64_559d_11eb_aa14_000d3aebc696row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_35753e64_559d_11eb_aa14_000d3aebc696" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_35753e64_559d_11eb_aa14_000d3aebc696level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_35753e64_559d_11eb_aa14_000d3aebc696row0_col0" class="data row0 col0" >28931</td>
#                         <td id="T_35753e64_559d_11eb_aa14_000d3aebc696row0_col1" class="data row0 col1" >327</td>
#             </tr>
#             <tr>
#                         <th id="T_35753e64_559d_11eb_aa14_000d3aebc696level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_35753e64_559d_11eb_aa14_000d3aebc696row1_col0" class="data row1 col0" >836</td>
#                         <td id="T_35753e64_559d_11eb_aa14_000d3aebc696row1_col1" class="data row1 col1" >2856</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: d5eae175-1011-4e88-8c1e-3f84e8a0af95,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/976ee174-3882-4721-b90a-b5fef6b72f24/resourceGroups/aml-quickstarts-134528/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-134528/PipelineRuns/PipelineSubmit/d5eae175-1011-4e88-8c1e-3f84e8a0af95)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  46a10248-13a1-420c-81ae-4ecffe0cd280

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
